# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df = pd.read_csv("calendar_events.csv")

print(df.head() )
# Out:
#              kind                etag                          id     status  \
# 0  calendar#event  "3346643666342000"  crstnj0607p57juckh2uhtur9c  confirmed
# 1  calendar#event  "3348014271204000"  sapmqns0pui4h9d2a83ebr1u40  confirmed
# 2  calendar#event  "3346972664712000"  6t1ja19g4ou170nqbc925jus68  confirmed
# 3  calendar#event  "3347099996980000"  2635o2670fo1ku0op992moqf24  confirmed
# 4  calendar#event  "3347955631652000"  c51oe9lf1hqp6cmahjnnckoats  confirmed
#
#                                             htmlLink  \
# 0  https://www.google.com/calendar/event?eid=Y3Jz...
# 1  https://www.google.com/calendar/event?eid=c2Fw...
# 2  https://www.google.com/calendar/event?eid=NnQx...
# 3  https://www.google.com/calendar/event?eid=MjYz...
# 4  https://www.google.com/calendar/event?eid=YzUx...
#
#                     created                   updated  \
# 0  2023-01-09T21:24:04.000Z  2023-01-10T03:37:13.171Z
# 1  2023-01-09T03:18:24.000Z  2023-01-18T01:58:55.602Z
# 2  2023-01-09T17:58:24.000Z  2023-01-12T01:18:52.356Z
# 3  2023-01-12T18:36:53.000Z  2023-01-12T18:59:58.490Z
# 4  2023-01-12T17:42:22.000Z  2023-01-17T17:50:15.826Z
#
#                          summary  \
# 0          Daijah W. (Aidan Lau)
# 1     Grace B. (Bruno Pena-Lepe)
# 2       Daijah W. (Emily Valova)
# 3  Maddie B. (Daisy Diaz-Garcia)
# 4      Charlotte M. (Jamie Choe)
#
#                                          description location  \
# 0  Teacher's Name/Email: Mr. Campos (dcampos24@cp...  Rm. 233
# 1  Revision of short essays to apply for summer a...  Rm. 233
# 2  I need my responses for the CIEE exchange prog...  Rm. 233
# 3  Walk-in<br><br>Date Visited: 1/12/2022<br>Writ...  Rm. 233
# 4  <span>bassette</span><br><span><br>What we wor...  Rm. 233
#
#                              creator  \
# 0  {'email': 'eacramarosso@cps.edu'}
# 1  {'email': 'eacramarosso@cps.edu'}
# 2  {'email': 'eacramarosso@cps.edu'}
# 3      {'email': 'lrcrabbe@cps.edu'}
# 4  {'email': 'eacramarosso@cps.edu'}
#
#                                            organizer  \
# 0  {'email': 'c_b1apq7apag81c7l18bh1kob8eo@group....
# 1  {'email': 'c_b1apq7apag81c7l18bh1kob8eo@group....
# 2  {'email': 'c_b1apq7apag81c7l18bh1kob8eo@group....
# 3  {'email': 'c_b1apq7apag81c7l18bh1kob8eo@group....
# 4  {'email': 'c_b1apq7apag81c7l18bh1kob8eo@group....
#
#                                                start  \
# 0  {'dateTime': '2023-01-09T15:30:00-06:00', 'tim...
# 1  {'dateTime': '2023-01-10T13:00:00-06:00', 'tim...
# 2  {'dateTime': '2023-01-11T15:00:00-06:00', 'tim...
# 3  {'dateTime': '2023-01-12T11:40:00-06:00', 'tim...
# 4  {'dateTime': '2023-01-12T11:40:00-06:00', 'tim...
#
#                                                  end  \
# 0  {'dateTime': '2023-01-09T15:55:00-06:00', 'tim...
# 1  {'dateTime': '2023-01-10T13:25:00-06:00', 'tim...
# 2  {'dateTime': '2023-01-11T15:25:00-06:00', 'tim...
# 3  {'dateTime': '2023-01-12T12:05:00-06:00', 'tim...
# 4  {'dateTime': '2023-01-12T12:05:00-06:00', 'tim...
#
#                                  iCalUID  sequence  \
# 0  crstnj0607p57juckh2uhtur9c@google.com         0
# 1  sapmqns0pui4h9d2a83ebr1u40@google.com         0
# 2  6t1ja19g4ou170nqbc925jus68@google.com         0
# 3  2635o2670fo1ku0op992moqf24@google.com         0
# 4  c51oe9lf1hqp6cmahjnnckoats@google.com         0
#
#                                            attendees  \
# 0  [{'email': 'aslau@cps.edu', 'responseStatus': ...
# 1  [{'email': 'bpena-lepe@cps.edu', 'responseStat...
# 2  [{'email': 'envalova@cps.edu', 'responseStatus...
# 3  [{'email': 'mmburdenski@cps.edu', 'responseSta...
# 4  [{'email': 'jchoe@cps.edu', 'responseStatus': ...
#
#                             hangoutLink  \
# 0  https://meet.google.com/yos-zutb-dpn
# 1  https://meet.google.com/ptp-krrm-cpw
# 2  https://meet.google.com/khn-wkcx-gyn
# 3                                   NaN
# 4  https://meet.google.com/imf-pzvb-ekj
#
#                                       conferenceData             reminders  \
# 0  {'createRequest': {'requestId': 'i4j31l6icp4a9...  {'useDefault': True}
# 1  {'createRequest': {'requestId': 'o854clq09rr9b...  {'useDefault': True}
# 2  {'createRequest': {'requestId': '05vk817qs1f8t...  {'useDefault': True}
# 3                                                NaN  {'useDefault': True}
# 4  {'createRequest': {'requestId': '9udco24747397...  {'useDefault': True}
#
#   eventType transparency guestsCanSeeOtherGuests
# 0   default          NaN                     NaN
# 1   default          NaN                     NaN
# 2   default          NaN                     NaN
# 3   default          NaN                     NaN
# 4   default          NaN                     NaN
